# %%
# Sprint 3A Tasks

# 1
x = 5
if x > 0:
    print("müsbət")
elif x < 0:
    print("mənfi")
else:
    print("sıfır")

# 2
n = 7
if n % 2 == 0:
    print("cüt")
else:
    print("tək")

# 3
a, b, c = 3, 7, 5
print(max(a, b, c))

# 4
day = 3
days = {1: "Bazar ertəsi", 2: "Çərşənbə axşamı", 3: "Çərşənbə", 4: "Cümə axşamı", 5: "Cümə", 6: "Şənbə", 7: "Bazar"}
print(days.get(day, "Yanlış gün"))

# 5
temp = 15
if temp < 0:
    print("soyuq")
elif temp <= 20:
    print("normal")
else:
    print("isti")

# 6
password = "mypassword"
if len(password) < 8:
    print("qısa")
elif len(password) <= 12:
    print("orta")
else:
    print("uzun")

# 7
x = 15
if x % 3 == 0 and x % 5 == 0:
    print("3 və 5")
elif x % 3 == 0:
    print("3")
elif x % 5 == 0:
    print("5")
else:
    print("heç biri")

# 8
for i in range(0, 21):
    if i % 2 == 0:
        print(i)

# 9
text = "Bağda ərik var idi …"
for char in text:
    print(char)

# 10
for i in range(1, 11):
    if i == 3:
        continue
    print(i)

# 11
i = 1
while True:
    if i % 5 == 0:
        print(i)
        break
    i += 1

# 12
lst = [1, 3, 5, 7, 9]
for idx, val in enumerate(lst):
    if val == 5:
        print(idx)
        break

# Sprint 3B Tasks

# 1
def salam():
    print("Salam, Dünya!")

salam()

# 2
def kub_hesabla(n):
    return n ** 3

print(kub_hesabla(3))

# 3
def birlesdir(word1, word2):
    return word1 + " " + word2

print(birlesdir("Salam", "Dünya"))

# 4
def cap_et(lst):
    for item in lst:
        print(item)

cap_et([1,2,3])

# 5
def toplam(*args):
    return sum(args)

print(toplam(1,2,3))

# 6
def ortalama(*args):
    if not args:
        return "Rəqəm yoxdur"
    return sum(args) / len(args)

print(ortalama(1,2,3))

# 7
def adlar_reqemler(**kwargs):
    for ad, reqem in kwargs.items():
        print(f"ad: {ad}, rəqəm: {reqem}")

adlar_reqemler(bir=1, iki=2)

# 8
def tip_yoxla(deyer):
    if isinstance(deyer, str):
        print("mətn")
    elif isinstance(deyer, (int, float)):
        print("rəqəm")
    else:
        print("başqa")

tip_yoxla(5)

# 9
def yas_kateqoriya():
    yas = int(input("Yaşınızı daxil edin: "))
    if yas < 18:
        print("Gənc")
    else:
        print("Yetkin")

# yas_kateqoriya() # Collab istifadəçi inputu üçün açıla bilər

# 10
def soz_uzunluq():
    soz = input("Bir söz daxil edin: ")
    print(len(soz))

# soz_uzunluq() # Collab istifadəçi inputu üçün açıla bilər
